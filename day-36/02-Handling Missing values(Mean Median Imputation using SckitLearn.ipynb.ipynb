# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('titanic_toy.csv')

# %%
df.head()
# Out:
#     Age     Fare  Family  Survived
# 0  22.0   7.2500       1         0
# 1  38.0  71.2833       1         1
# 2  26.0   7.9250       0         1
# 3  35.0  53.1000       1         1
# 4  35.0   8.0500       0         0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       714 non-null    float64
#  1   Fare      846 non-null    float64
#  2   Family    891 non-null    int64
#  3   Survived  891 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 28.0 KB

# %%
df.isnull().mean()*100
# Out:
# Age         19.865320
# Fare         5.050505
# Family       0.000000
# Survived     0.000000
# dtype: float64

# %%
X = df.drop(columns=['Survived'])
y = df['Survived']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
#we will use two imputer in two cols , one using median and another using mean
#fro age col -> we will impute using median
#for Fare col-> we will impute using mean

# %%
from sklearn.impute import SimpleImputer
imputer1 = SimpleImputer(strategy='median')
imputer2 = SimpleImputer(strategy='mean')

# %%
from sklearn.compose import ColumnTransformer

trf = ColumnTransformer([
    ('imputer1', imputer1, ['Age']),
    ('imputer2', imputer2, ['Fare']),
], remainder='passthrough', force_int_remainder_cols=False)  # Suppresses the warning

# %%
trf.fit(X_train)
# Out:
# ColumnTransformer(force_int_remainder_cols=False, remainder='passthrough',
#                   transformers=[('imputer1', SimpleImputer(strategy='median'),
#                                  ['Age']),
#                                 ('imputer2', SimpleImputer(), ['Fare'])])

# %%
trf.named_transformers_['imputer1'].statistics_
#that is the median value of age
# Out:
# array([28.75])

# %%
trf.named_transformers_['imputer2'].statistics_
#that is the mean value of fare
# Out:
# array([32.61759689])

# %%
X_train_transformed= trf.transform(X_train)
X_test_transformed= trf.transform(X_test)

# %%
X_train_transformed
# Out:
# array([[ 40.    ,  27.7208,   0.    ],
#        [  4.    ,  16.7   ,   2.    ],
#        [ 47.    ,   9.    ,   0.    ],
#        ...,
#        [ 71.    ,  49.5042,   0.    ],
#        [ 28.75  , 221.7792,   0.    ],
#        [ 28.75  ,  25.925 ,   0.    ]])

# %%
X_test_transformed
# Out:
# array([[ 42.        ,  26.2875    ,   0.        ],
#        [ 21.        ,   8.05      ,   0.        ],
#        [ 24.        ,  65.        ,   3.        ],
#        [ 28.        ,  56.4958    ,   0.        ],
#        [ 17.        ,   7.925     ,   6.        ],
#        [ 30.        ,   7.8958    ,   0.        ],
#        [ 80.        ,  30.        ,   0.        ],
#        [ 25.        ,   7.25      ,   0.        ],
#        [ 50.        , 133.65      ,   2.        ],
#        [ 25.        ,  26.        ,   1.        ],
#        [ 35.        ,  26.        ,   0.        ],
#        [ 35.        ,  90.        ,   1.        ],
#        [ 55.        ,  16.        ,   0.        ],
#        [ 28.75      ,  56.4958    ,   0.        ],
#        [ 28.75      ,  56.4958    ,   0.        ],
#        [ 19.        ,   7.8542    ,   1.        ],
#        [ 28.75      ,  15.2458    ,   2.        ],
#        [ 49.        ,   0.        ,   0.        ],
# ...
